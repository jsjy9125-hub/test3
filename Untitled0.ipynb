# %% [markdown]
# <a href="https://colab.research.google.com/github/jsjy9125-hub/test3/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("김달라대로로롱")
# Out:
# 김달라대로로롱
